# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer # n-gram
from wordcloud import WordCloud
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
file_path = './../Fed1_dataset/Interest_rate_prediction.csv'

# FED_ir의 의미 : FED interest rate
df_irp = pd.read_csv(file_path)

df_irp.head()
# Out:
#          DATE  DFEDTARU  DFEDTARL  IR_FORCAST  GDPGR  UNRATE   PCEPI    TNX  \
# 0  2008-12-01      0.25       0.0        0.50   -8.5     7.3  88.098  2.244
# 1  2009-01-01      0.25       0.0        0.25   -4.5     7.8  88.108  2.844
# 2  2009-02-01      0.25       0.0        0.25   -4.5     8.3  88.266  3.041
# 3  2009-03-01      0.25       0.0        0.25   -4.5     8.7  88.169  2.685
# 4  2009-04-01      0.25       0.0        0.25   -0.7     9.0  88.295  3.124
#
#       USD  KR_IR  ECB_IR                                            BB_text  \
# 0  1259.5    3.0    2.50  Prepared at the Federal Reserve Bank of Minnea...
# 1  1379.5    2.5    2.00  Prepared at the Federal Reserve Bank of St. Lo...
# 2  1534.0    2.0    2.00  Prepared at the Federal Reserve Bank of St. Lo...
# 3  1383.5    2.0    1.50  Prepared at the Federal Reserve Bank of San Fr...
# 4  1282.0    2.0    1.25  Prepared at the Federal Reserve Bank of Dallas...
#
#    BB_neg  BB_neu  BB_pos  BB_sentiment  DATE_YM
# 0   0.080   0.839   0.082        0.9133  2008-12
# 1   0.061   0.865   0.074        0.9952  2009-01
# 2   0.061   0.865   0.074        0.9952  2009-02
# 3   0.083   0.839   0.078        0.5459  2009-03
# 4   0.092   0.826   0.082       -0.6999  2009-04

# %% [markdown]
# 1단계 : 정형 데이터 EDA

# %%
df_irp['DATE'] = pd.to_datetime(df_irp['DATE'])

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['DFEDTARL'])
plt.title('월별 기준금리 상한')
plt.xlabel('월')
plt.ylabel('기준금리 상한')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['DFEDTARU'])
plt.title('월별 기준금리 하한')
plt.xlabel('월')
plt.ylabel('기준금리 하한')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['IR_FORCAST'])
plt.title('월별 기준 금리 예측치')
plt.xlabel('월')
plt.ylabel('기준 금리 예측치')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['GDPGR'])
plt.title('월별 실질 국내총생산')
plt.xlabel('월')
plt.ylabel('실질 국내총생산')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['UNRATE'])
plt.title('월별 실업률')
plt.xlabel('월')
plt.ylabel('실질 국내총생산')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['PCEPI'])
plt.title('월별 개인 소비 지출: 체인형 가격 지수')
plt.xlabel('월')
plt.ylabel('개인 소비 지출: 체인형 가격 지수')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['TNX'])
plt.title('월별 명목이자율(미국 국채 10년물(^TNX))')
plt.xlabel('월')
plt.ylabel('명목이자율(미국 국채 10년물(^TNX))')
plt.show()

# %% [markdown]
# 환율 데이터의 경우 그래프가 이상하게 나와서 아래와 같은 절차로 데이터 확인
# 1. 시작일~2010-01-01 기간동안으로 그래프 그리기=>환율이 낮은 것이 상단에 위치
# 2. datatype 확인 결과 환율이 다른 컬럼과 달리 object type으로 되어 있음=>
# 3. float64로 변경 시도(df_irp['USD'] = pd.to_numeric(df_irp['USD']))했으나 오류 발생하여 크롤링 프로그램 재점검

# %%
df_irp_filter = df_irp[df_irp['DATE']<='2010-01-01']
df_irp_filter['DATE'] = pd.to_datetime(df_irp_filter['DATE'])

plt.figure(figsize=(10,6))
plt.plot(df_irp_filter['DATE'], df_irp_filter['USD'])
plt.title('월별 USD환율')
plt.xlabel('월')
plt.ylabel('USD환율')
plt.show()
# Out:
# C:\Users\dybae\AppData\Local\Temp\ipykernel_21672\2582805857.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irp_filter['DATE'] = pd.to_datetime(df_irp_filter['DATE'])

# %%
specific_columns = ['DATE', 'USD']
df_irp.head(20)[specific_columns]
# Out:
#          DATE       USD
# 0  2009-01-01  1,259.50
# 1  2009-02-01  1,379.50
# 2  2009-03-01  1,534.00
# 3  2009-04-01  1,379.50
# 4  2009-05-01  1,282.00
# 5  2009-06-01  1,237.20
# 6  2009-07-01  1,267.70
# 7  2009-08-01  1,228.50
# 8  2009-09-01  1,240.60
# 9  2009-10-01  1,178.30
# 10 2009-11-01  1,182.50
# 11 2009-12-01  1,161.10
# 12 2010-01-01  1,164.50
# 13 2010-02-01  1,169.50
# 14 2010-03-01  1,160.00
# 15 2010-04-01  1,126.40
# 16 2010-05-01  1,108.40
# 17 2010-06-01  1,216.50
# 18 2010-07-01  1,228.70
# 19 2010-08-01  1,182.70

# %%
df_irp.dtypes
# Out:
# DATE               datetime64[ns]
# index                       int64
# DFEDTARU                  float64
# DFEDTARL                  float64
# IR_FORCAST                float64
# A191RL1Q225SBEA           float64
# UNRATE                    float64
# PCEPI                     float64
# TNX                       float64
# USD                        object
# KR_IR                     float64
# ECB_IR                    float64
# BB_text                    object
# BB_neg                    float64
# BB_neu                    float64
# BB_pos                    float64
# BB_sentiment              float64
# DATE_YM                    object
# dtype: object

# %%
df_irp['USD'] = pd.to_numeric(df_irp['USD'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,259.50"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df_irp['USD'] = pd.to_numeric(df_irp['USD'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     237         or isinstance(values_dtype, StringDtype)
#     238         and not values_dtype.storage == "pyarrow_numpy",
#     239     )
#     240 except (ValueError, TypeError):
#     241     if errors == "raise":
#
# File lib.pyx:2433, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,259.50" at position 0

# %% [markdown]
# 여기서부터 정상 출력

# %%
df_irp['DATE'] = pd.to_datetime(df_irp['DATE'])

plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['USD'])
plt.title('월별 한은 USD환율')
plt.xlabel('월')
plt.ylabel('한은 USD환율')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['KR_IR'])
plt.title('월별 한은 기준 금리')
plt.xlabel('월')
plt.ylabel('한은 기준 금리')
plt.show()

# %%
df_irp['DATE'] = pd.to_datetime(df_irp['DATE'])

plt.figure(figsize=(10,6))
plt.plot(df_irp['DATE'], df_irp['ECB_IR'])
plt.title('월별 ECB 기준 금리')
plt.xlabel('월')
plt.ylabel('ECB 기준 금리')
plt.show()

# %%
dic_irp = {
    'DATE': '일자',
    'DFEDTARU': '연준 기준 금리 상한',
    'DFEDTARL': '연준 기준 금리 하한',
    'IR_FORCAST': '연준 기준 금리 예측치',
    'GDPGR': '실질 국내총생산 성장률',
    'UNRATE': '실업률',
    'PCEPI': '개인 소비 지출: 체인형 가격 지수',
    'TNX': '명목이자율',
    'USD': '한은 USD환율',
    'KR_IR': '한은 기준 금리',
    'ECB_IR': 'ECB 기준 금리',
    'BB_neg': 'Beige book 부정',
    'BB_neu': 'Beige book 중립',
    'BB_pos': 'Beige book 긍정',
    'BB_sentiment': 'Beige book 감정'
}
keys = list(dic_irp.keys())

# 상관관계 계산
for column1 in keys:
    if column1 in ('DATE', 'DFEDTARL'):
        continue
    for column2 in keys:
        if column2 in ('DATE', 'DFEDTARL', column1):
            continue
        # 상관관계 계산
        correlation = df_irp[column1].corr(df_irp[column2])
        print(f'correlation {column1}/{column2}: {correlation}')
# Out:
# correlation DFEDTARU/IR_FORCAST: 0.9975598386883944
# correlation DFEDTARU/GDPGR: 0.029379102962898026
# correlation DFEDTARU/UNRATE: -0.5822525551329388
# correlation DFEDTARU/PCEPI: 0.8018107356098094
# correlation DFEDTARU/TNX: 0.6268462909001203
# correlation DFEDTARU/USD: 0.6144362172770361
# correlation DFEDTARU/KR_IR: 0.4550514138692885
# correlation DFEDTARU/ECB_IR: 0.7547350032255785
# correlation DFEDTARU/BB_neg: 0.20104080809250816
# correlation DFEDTARU/BB_neu: -0.300769710127912
# correlation DFEDTARU/BB_pos: 0.15095299070422388
# correlation DFEDTARU/BB_sentiment: 0.11207153936037625
# correlation IR_FORCAST/DFEDTARU: 0.9975598386883943
# correlation IR_FORCAST/GDPGR: 0.02212925967670242
# correlation IR_FORCAST/UNRATE: -0.5852493340809778
# correlation IR_FORCAST/PCEPI: 0.8018096221197861
# correlation IR_FORCAST/TNX: 0.6172018177582136
# correlation IR_FORCAST/USD: 0.6174824716857112
# correlation IR_FORCAST/KR_IR: 0.4496254612163794
# correlation IR_FORCAST/ECB_IR: 0.7541907382423486
# correlation IR_FORCAST/BB_neg: 0.20094842131198315
# correlation IR_FORCAST/BB_neu: -0.30155161351147547
# correlation IR_FORCAST/BB_pos: 0.15175564309782627
# correlation IR_FORCAST/BB_sentiment: 0.11297200459792656
# correlation GDPGR/DFEDTARU: 0.029379102962898022
# correlation GDPGR/IR_FORCAST: 0.022129259676702418
# correlation GDPGR/UNRATE: -0.16498540711656595
# correlation GDPGR/PCEPI: 0.07550766303172143
# correlation GDPGR/TNX: -0.022938493117322035
# correlation GDPGR/USD: -0.13086706748757218
# correlation GDPGR/KR_IR: -0.05279875233303477
# correlation GDPGR/ECB_IR: -0.02074053979587857
# correlation GDPGR/BB_neg: -0.10635230417645691
# correlation GDPGR/BB_neu: -0.25219160476582647
# correlation GDPGR/BB_pos: 0.3012631701551409
# correlation GDPGR/BB_sentiment: 0.5228822941256257
# correlation UNRATE/DFEDTARU: -0.5822525551329389
# correlation UNRATE/IR_FORCAST: -0.5852493340809777
# correlation UNRATE/GDPGR: -0.16498540711656598
# correlation UNRATE/PCEPI: -0.6728869602785177
# correlation UNRATE/TNX: -0.1470341080455086
# correlation UNRATE/USD: -0.2031727679747232
# correlation UNRATE/KR_IR: 0.09222729335273368
# correlation UNRATE/ECB_IR: -0.06663111729669167
# correlation UNRATE/BB_neg: 0.21324576943000895
# correlation UNRATE/BB_neu: 0.4974083462846816
# correlation UNRATE/BB_pos: -0.5918571093871194
# correlation UNRATE/BB_sentiment: -0.41511508185946705
# correlation PCEPI/DFEDTARU: 0.8018107356098094
# correlation PCEPI/IR_FORCAST: 0.8018096221197861
# correlation PCEPI/GDPGR: 0.07550766303172143
# correlation PCEPI/UNRATE: -0.6728869602785178
# correlation PCEPI/TNX: 0.27187782820631506
# correlation PCEPI/USD: 0.5451568641198198
# correlation PCEPI/KR_IR: 0.10581547164413818
# correlation PCEPI/ECB_IR: 0.4850699140783283
# correlation PCEPI/BB_neg: 0.23874726901393473
# correlation PCEPI/BB_neu: -0.6075809418968702
# correlation PCEPI/BB_pos: 0.4099053907363867
# correlation PCEPI/BB_sentiment: 0.10616969671161813
# correlation TNX/DFEDTARU: 0.6268462909001203
# correlation TNX/IR_FORCAST: 0.6172018177582136
# correlation TNX/GDPGR: -0.022938493117322035
# correlation TNX/UNRATE: -0.1470341080455086
# correlation TNX/PCEPI: 0.27187782820631506
# correlation TNX/USD: 0.45330459899914144
# correlation TNX/KR_IR: 0.6397465350395191
# correlation TNX/ECB_IR: 0.7069750644355154
# correlation TNX/BB_neg: 0.12045155845929727
# correlation TNX/BB_neu: 0.07309977879060099
# correlation TNX/BB_pos: -0.143860622889754
# correlation TNX/BB_sentiment: 0.10238269143631444
# correlation USD/DFEDTARU: 0.6144362172770361
# correlation USD/IR_FORCAST: 0.6174824716857112
# correlation USD/GDPGR: -0.13086706748757218
# correlation USD/UNRATE: -0.2031727679747232
# correlation USD/PCEPI: 0.5451568641198198
# correlation USD/TNX: 0.4533045989991415
# correlation USD/KR_IR: 0.26937828517822127
# correlation USD/ECB_IR: 0.6466938165962332
# correlation USD/BB_neg: 0.4855905911471876
# correlation USD/BB_neu: -0.11769336452287929
# correlation USD/BB_pos: -0.19472121049534782
# correlation USD/BB_sentiment: -0.16720989852322427
# correlation KR_IR/DFEDTARU: 0.4550514138692885
# correlation KR_IR/IR_FORCAST: 0.4496254612163794
# correlation KR_IR/GDPGR: -0.05279875233303478
# correlation KR_IR/UNRATE: 0.09222729335273368
# correlation KR_IR/PCEPI: 0.1058154716441382
# correlation KR_IR/TNX: 0.6397465350395191
# correlation KR_IR/USD: 0.26937828517822127
# correlation KR_IR/ECB_IR: 0.7548039549773513
# correlation KR_IR/BB_neg: 0.03163462922469171
# correlation KR_IR/BB_neu: 0.22180492653992645
# correlation KR_IR/BB_pos: -0.2234747283937436
# correlation KR_IR/BB_sentiment: 0.15680084799204108
# correlation ECB_IR/DFEDTARU: 0.7547350032255785
# correlation ECB_IR/IR_FORCAST: 0.7541907382423486
# correlation ECB_IR/GDPGR: -0.02074053979587857
# correlation ECB_IR/UNRATE: -0.06663111729669169
# correlation ECB_IR/PCEPI: 0.4850699140783283
# correlation ECB_IR/TNX: 0.7069750644355154
# correlation ECB_IR/USD: 0.6466938165962332
# correlation ECB_IR/KR_IR: 0.7548039549773513
# correlation ECB_IR/BB_neg: 0.27992012576770636
# correlation ECB_IR/BB_neu: 0.006653196548783113
# correlation ECB_IR/BB_pos: -0.18028725478515562
# correlation ECB_IR/BB_sentiment: 0.03243150367034776
# correlation BB_neg/DFEDTARU: 0.20104080809250816
# correlation BB_neg/IR_FORCAST: 0.20094842131198315
# correlation BB_neg/GDPGR: -0.10635230417645691
# correlation BB_neg/UNRATE: 0.21324576943000895
# correlation BB_neg/PCEPI: 0.23874726901393473
# correlation BB_neg/TNX: 0.12045155845929727
# correlation BB_neg/USD: 0.48559059114718767
# correlation BB_neg/KR_IR: 0.03163462922469171
# correlation BB_neg/ECB_IR: 0.27992012576770636
# correlation BB_neg/BB_neu: -0.20679541215271127
# correlation BB_neg/BB_pos: -0.43124417045465957
# correlation BB_neg/BB_sentiment: -0.4868799321518386
# correlation BB_neu/DFEDTARU: -0.3007697101279119
# correlation BB_neu/IR_FORCAST: -0.30155161351147547
# correlation BB_neu/GDPGR: -0.25219160476582647
# correlation BB_neu/UNRATE: 0.4974083462846816
# correlation BB_neu/PCEPI: -0.6075809418968702
# correlation BB_neu/TNX: 0.073099778790601
# correlation BB_neu/USD: -0.11769336452287929
# correlation BB_neu/KR_IR: 0.22180492653992645
# correlation BB_neu/ECB_IR: 0.006653196548783112
# correlation BB_neu/BB_neg: -0.2067954121527113
# correlation BB_neu/BB_pos: -0.7933486914823679
# correlation BB_neu/BB_sentiment: -0.16952244708311198
# correlation BB_pos/DFEDTARU: 0.15095299070422386
# correlation BB_pos/IR_FORCAST: 0.15175564309782627
# correlation BB_pos/GDPGR: 0.30126317015514087
# correlation BB_pos/UNRATE: -0.5918571093871194
# correlation BB_pos/PCEPI: 0.4099053907363867
# correlation BB_pos/TNX: -0.143860622889754
# correlation BB_pos/USD: -0.1947212104953478
# correlation BB_pos/KR_IR: -0.2234747283937436
# correlation BB_pos/ECB_IR: -0.18028725478515562
# correlation BB_pos/BB_neg: -0.4312441704546595
# correlation BB_pos/BB_neu: -0.7933486914823679
# correlation BB_pos/BB_sentiment: 0.46164711145154014
# correlation BB_sentiment/DFEDTARU: 0.11207153936037624
# correlation BB_sentiment/IR_FORCAST: 0.11297200459792656
# correlation BB_sentiment/GDPGR: 0.5228822941256256
# correlation BB_sentiment/UNRATE: -0.415115081859467
# correlation BB_sentiment/PCEPI: 0.10616969671161813
# correlation BB_sentiment/TNX: 0.10238269143631444
# correlation BB_sentiment/USD: -0.16720989852322427
# correlation BB_sentiment/KR_IR: 0.15680084799204108
# correlation BB_sentiment/ECB_IR: 0.03243150367034776
# correlation BB_sentiment/BB_neg: -0.4868799321518386
# correlation BB_sentiment/BB_neu: -0.16952244708311198
# correlation BB_sentiment/BB_pos: 0.46164711145154014

# %%
2. 비정형 데이터 EDA

# %%
# 접속사들이 주로 나와서 전처리 필요
plt.figure(figsize=(8,6))

# 단어 빈도 계산
word_counts = Counter(' '.join(df_irp['BB_text']).split())

# 상위 20개 단어 시각화
common_words = word_counts.most_common(20)
words, counts = zip(*common_words)

plt.bar(words, counts)
plt.xticks(rotation=90)
plt.show()

# %%
df_irp['BB_text'] = df_irp['BB_text'].str.lower()  # 소문자로
df_irp['BB_text'] = df_irp['BB_text'].str.strip()  # 앞뒤 공백 제거
df_irp['BB_text'] = df_irp['BB_text'].str.replace('\s+', ' ', regex=True)  # 중간 공백 제거
# 숫자, 대문자, 소문자 알파벳 및 공백을 제외한 모든 문자 제거
df_irp['BB_text'] = df_irp['BB_text'].apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))

# %%
# 불용어 제거
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

df_irp['BB_text'] = df_irp['BB_text'].apply(remove_stopwords)

# %%
# 접속사들이 주로 나와서 전처리 필요
plt.figure(figsize=(8,6))

# 단어 빈도 계산
word_counts = Counter(' '.join(df_irp['BB_text']).split())

# 상위 20개 단어 시각화
common_words = word_counts.most_common(20)
words, counts = zip(*common_words)

plt.bar(words, counts)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))

# 문서 길이 계산
df_irp['text_length'] = df_irp['BB_text'].apply(lambda x: len(x.split()))

# 문서 길이 분포 시각화
plt.hist(df_irp['text_length'], bins=50)
plt.show()

# %%
plt.figure(figsize=(8,6))

# 바이그램 분석
vectorizer = CountVectorizer(ngram_range=(2, 2))
X2 = vectorizer.fit_transform(df_irp['BB_text'])

# 상위 20개 바이그램 시각화
bi_grams = X2.sum(axis=0).A1
bi_gram_counts = Counter(dict(zip(vectorizer.get_feature_names_out(), bi_grams)))
common_bi_grams = bi_gram_counts.most_common(20)

bi_grams, counts = zip(*common_bi_grams)

plt.bar(bi_grams, counts)
plt.xticks(rotation=90)
plt.show()

# %%
# 단어 빈도 기반 WordCloud 생성
wordcloud = WordCloud(width=800, height=400).generate(' '.join(df_irp['BB_text']))

plt.figure(figsize=(12, 9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 연방준비은행 지역 목록 제거st louis와 같은 경우도 감안
federal_reserve_banks = [
    "boston", 
    "new york", 
    "philadelphia", 
    "cleveland", 
    "richmond", 
    "atlanta", 
    "chicago", 
    "st. louis", 
    "minneapolis", 
    "kansas city", 
    "dallas", 
    "san francisco",
    "st",
    "louis"
]

# 연방준비은행 지역 필터링 함수
def remove_federal_reserve_banks(text, bank_list):
    # 소문자 변환 및 정규표현식을 사용하여 지역 이름 제거
    for bank in bank_list:
        bank_pattern = re.compile(re.escape(bank), re.IGNORECASE)
        text = bank_pattern.sub('', text)
    return text

# 연방준비은행 지역 제거
df_irp['BB_text'] = df_irp['BB_text'].apply(lambda x: remove_federal_reserve_banks(x, federal_reserve_banks))

# %%
# 접속사들이 주로 나와서 전처리 필요
plt.figure(figsize=(8,6))

# 단어 빈도 계산
word_counts = Counter(' '.join(df_irp['BB_text']).split())

# 상위 20개 단어 시각화
common_words = word_counts.most_common(20)
words, counts = zip(*common_words)

plt.bar(words, counts)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))

# 문서 길이 계산
df_irp['text_length'] = df_irp['BB_text'].apply(lambda x: len(x.split()))

# 문서 길이 분포 시각화
plt.hist(df_irp['text_length'], bins=50)
plt.show()

# %%
plt.figure(figsize=(8,6))

# 바이그램 분석
vectorizer = CountVectorizer(ngram_range=(2, 2))
X2 = vectorizer.fit_transform(df_irp['BB_text'])

# 상위 20개 바이그램 시각화
bi_grams = X2.sum(axis=0).A1
bi_gram_counts = Counter(dict(zip(vectorizer.get_feature_names_out(), bi_grams)))
common_bi_grams = bi_gram_counts.most_common(20)

bi_grams, counts = zip(*common_bi_grams)

plt.bar(bi_grams, counts)
plt.xticks(rotation=90)
plt.show()

# %%
# 단어 빈도 기반 WordCloud 생성
wordcloud = WordCloud(width=800, height=400).generate(' '.join(df_irp['BB_text']))

plt.figure(figsize=(12, 9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 감정분석 : 전처리 이전과 이후 비교

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dybae\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    sentiment = sia.polarity_scores(text)
    return sentiment['neg'], sentiment['neu'], sentiment['pos'], sentiment['compound']

df_irp[['f_neg', 'f_neu', 'f_pos', 'f_sentiment']] = df_irp['BB_text'].apply(lambda text: pd.Series(get_vader_sentiment(text)))

df_irp
# Out:
#           DATE  DFEDTARU  DFEDTARL  IR_FORCAST  GDPGR  UNRATE    PCEPI    TNX  \
# 0   2008-12-01      0.25      0.00        0.50   -8.5     7.3   88.098  2.244
# 1   2009-01-01      0.25      0.00        0.25   -4.5     7.8   88.108  2.844
# 2   2009-02-01      0.25      0.00        0.25   -4.5     8.3   88.266  3.041
# 3   2009-03-01      0.25      0.00        0.25   -4.5     8.7   88.169  2.685
# 4   2009-04-01      0.25      0.00        0.25   -0.7     9.0   88.295  3.124
# ..         ...       ...       ...         ...    ...     ...      ...    ...
# 183 2024-03-01      5.50      5.25        5.50    1.4     3.8  122.782  4.206
# 184 2024-04-01      5.50      5.25        5.50    2.8     3.9  123.109  4.686
# 185 2024-05-01      5.50      5.25        5.50    2.8     4.0  123.146  4.514
# 186 2024-06-01      5.50      5.25        5.50    2.8     4.1  123.243  4.343
# 187 2024-07-01      5.50      5.25        5.50    2.8     4.1  123.243  4.143
#
#         USD  KR_IR  ...  BB_neg BB_neu  BB_pos  BB_sentiment  DATE_YM  \
# 0    1259.5    3.0  ...   0.080  0.839   0.082        0.9133  2008-12
# 1    1379.5    2.5  ...   0.061  0.865   0.074        0.9952  2009-01
# 2    1534.0    2.0  ...   0.061  0.865   0.074        0.9952  2009-02
# 3    1383.5    2.0  ...   0.083  0.839   0.078        0.5459  2009-03
# 4    1282.0    2.0  ...   0.092  0.826   0.082       -0.6999  2009-04
# ..      ...    ...  ...     ...    ...     ...           ...      ...
# 183  1347.2    3.5  ...   0.056  0.797   0.147        0.9991  2024-03
# 184  1382.0    3.5  ...   0.068  0.807   0.126        0.9974  2024-04
# 185  1384.5    3.5  ...   0.076  0.783   0.141        0.9982  2024-05
# 186  1376.7    3.5  ...   0.076  0.783   0.141        0.9982  2024-06
# 187  1385.3    3.5  ...   0.051  0.796   0.153        0.9992  2024-07
#
#      text_length  f_neg  f_neu  f_pos  f_sentiment
# 0            916  0.111  0.804  0.085      -0.9594
# 1           1451  0.109  0.787  0.103      -0.6317
# 2           1451  0.109  0.787  0.103      -0.6317
# 3           1376  0.116  0.786  0.098      -0.8791
# 4           1295  0.124  0.779  0.097      -0.9705
# ..           ...    ...    ...    ...          ...
# 183          824  0.067  0.793  0.141       0.9966
# 184          790  0.071  0.813  0.117       0.9886
# 185          817  0.072  0.794  0.135       0.9953
# 186          817  0.072  0.794  0.135       0.9953
# 187          805  0.054  0.804  0.143       0.9970
#
# [188 rows x 22 columns]

# %%
# 감정 합쳐서 보여주기

# 플롯 생성
plt.figure(figsize=(10, 6))
plt.plot(df_irp['DATE'], df_irp['BB_sentiment'], label='Sentiment')
plt.plot(df_irp['DATE'], df_irp['f_sentiment'], label='F_Sentiment')

# 제목과 레이블 설정
plt.title('Sentiment and F_Sentiment over Time')
plt.xlabel('Date')
plt.ylabel('Sentiment Scores')
plt.legend()
# 플롯 보여주기
plt.show()

# %%
# fiter 안된 감점
plt.figure(figsize=(10, 6))
plt.plot(df_irp['DATE'], df_irp['BB_sentiment'], label='Sentiment')

# 제목과 레이블 설정
plt.title('Sentiment over Time')
plt.xlabel('Date')
plt.ylabel('Sentiment Scores')
plt.legend()
# 플롯 보여주기
plt.show()

# %%
# fiter 된 감점
plt.figure(figsize=(10, 6))
plt.plot(df_irp['DATE'], df_irp['f_sentiment'], label='Fitered Sentiment')

# 제목과 레이블 설정
plt.title('Fitered Sentiment over Time')
plt.xlabel('Date')
plt.ylabel('Fitered Sentiment Scores')
plt.legend()
# 플롯 보여주기
plt.show()
